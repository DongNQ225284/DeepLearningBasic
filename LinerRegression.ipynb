# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Bài toán hồi quy tuyến tính (Liner Regression)
# Sếp đưa cho bạn một bảng dữ liệu số có các trường $x_1, x_2, ..., x_m, y$
# Dữ liệu dòng thứ $i$ là $x_1^{(i)}, x_2^{(i)}, ... , x_m^{(i)}, y^{(i)}$
# Nhiệm vụ của bạn, căn cứ vào dữ liệu đã cho, bạn nhập một input $x_1^{(k)}, x_2^{(k)}, ... , x_m^{(k)}$ và mô hình của bạn phải trả ra được $y^{(k)}$ gần đúng
# Để giải quyết, bạn có ý tưởng là xây dựng một hàm số $y = w_0 + w_1.x_1 + ... + w_m.x_m (*)$
# Và bây giờ, nhiệm vụ của bạn là đi tìm $w_0, w_1, ..., w_m$
#
# Nếu để ý thì phương trình $(*)$ là phương trình tuyến tính, nên bài toán người được gọi là bài toán hồi quy tuyến tính
#
#
# ### Giá trị dự đoán của model
# $\hat{y}_1 = w_0 + w_1.x_1^{(1)} + ... + w_m.w_m^{(1)}$
# ...
# $\hat{y}_i = w_0 + w_1.x_1^{(i)} + ... + w_m.w_m^{(i)}$
# ...
# $\hat{y}_N = w_0 + w_1.x_1^{(N)} + ... + w_m.w_m^{(N)}$
#
#
# Ta có thể sử dụng ma trận để viết lại công thức gọn hơn.
#
# Đặt:
# $X = \begin{bmatrix} 1 & x_1^{(1)} & ... & x_m^{(1)} \\ 1 & x_1^{(2)} & ... & x_m^{(2)} \\ ... & ... & ... & ... \\ 1 & x_1^{(N)} & ... & x_m^{(N)} \end{bmatrix}_{N \times M}$,
# $W = \begin{bmatrix} w_0 \\ w_1 \\ ... \\ w_m \end{bmatrix}_{M \times 1}$,
# $\hat{Y} = \begin{bmatrix} \hat{y_1} \\ \hat{y_2} \\ ... \\ \hat{y_N} \end{bmatrix}_{N \times 1}$
#
# Khi đó: $\hat{Y} = X \times W$
#
# Nhiệm vụ trở thành tìm $W$ để $\hat{Y}$ giống $Y$ nhất

# %%
def get_value(w, X):
    X = np.hstack((np.ones((X.shape[0], 1)), X))
    return X @ w

# %% [markdown]
# ### Hàm mất mát
# Giá trị sai số trên mỗi mẫu dữ liệu: $L_i = (\hat{y_i} - y_i)^2 $
# Hàm mất mát (loss function): $J(x) = \sum_{i = 1}^N(L_i) = \sum_{i = 1}^N(\hat{y_i} - y_i)^2$
# Mục tiêu là đi tối thiểu hóa hàm mất mát với bộ dữ liệu đã cho

# %%
def get_loss_function(w, data):
    X = data[:, :-1]
    y = data[:, -1].reshape(-1, 1)
    Y = get_value(w, X)
    return np.sum((Y - y) ** 2)

# %% [markdown]
# ### Vector Gradient
# Đạo hàm của hàm số $f(x)$ cho ta biết độ dốc của đồ thị và hướng tăng của hàm số.
# Ví dụ: $f(x) = x^2 $ có $f'(x) = 2x$
# Xét dấu của $f'(2) = 4 > 0$ như vậy khi tăng giá trị $x$ thì $f(x)$ sẽ tăng.
# Xét dấu của $f'(-2) = -4 < 0$ như vậy khi giảm giá trị $x$ thì $f(x)$ sẽ tăng.
#
# Tổng quát hơn, xét hàm nhiều biến $f(x_1, ..., x_n)$ với $x_i \in R$
# Đạo hàm riêng theo $x_i$ tại $M(a_1, ..., a_n) \in R^n$ là $\frac{\partial f}{\partial x_i}(M)$.
# Dấu của $\frac{\partial f}{\partial x_i}(M)$ cho biết hướng $a_i$ thay đổi để giá trị $f(a_0, a_1, ..., a_n)$ tăng
#
# Vector Gradient tại $M$: $\vec{\triangledown}(M) = \begin{bmatrix} \frac{\partial f}{\partial x_1}(M) & ... & \frac{\partial f}{\partial x_n}(M) \end{bmatrix}^T $ cho biết hướng $M$ di chuyển để $f(M)$ tăng.
#
# ### Xác định Vector Gradient cho hàm loss funtion $J(x)$
# Với $J(x) = \sum_{i = 1}^N(L_i) = \sum_{i = 1}^N(\hat{y_i} - y_i)^2$
# Giả sử với lời giải hiện tại là $M^{(k)}(w_0, w_1, ..., w_m)$
#
# $\vec{\triangledown}(M^{(k)}) = \begin{bmatrix} \frac{\partial J}{\partial w_0}(M^{(k)}) & ... & \frac{\partial J}{\partial x_m}(M^{(k)}) \end{bmatrix}^T $
#
# Để cho gọn thì chúng ta bỏ $M^{(i)}$, và những đạo hàm sau, ta ngầm hiểu là tính tại $M^{(i)}$:
# $\vec{\triangledown} = \begin{bmatrix} \frac{\partial J}{\partial w_0} & ... & \frac{\partial J}{\partial x_m} \end{bmatrix}^T $
# + $\frac{\partial J}{\partial w_j} = \sum_{i = 1}^N\frac{\partial L_i}{\partial w_j}$
# + $\frac{\partial L_i}{\partial w_j} = \frac{\partial L_i}{\partial \hat{y}^{(i)}} \times \frac{\partial \hat{y}^{(i)}}{\partial w_j} $
#     + $\frac{\partial L_i}{\partial \hat{y}^{(i)}} = 2(\hat{y}^{(i)} - y^{(i)})$
#     + $\frac{\partial \hat{y}^{(i)}}{\partial w_j} = x_j^{(i)}$
#
# Thế ngược trở lại ta được: $\frac{\partial J}{\partial w_j} = 2\sum_{i = 1}^N(x_j^{(i)}.(\hat{y}^{(i)} - y^{(i)}))$
#
# Với phép đặt ban đầu: $\vec{\triangledown} = 2 X^T . (\hat{Y} - Y)$

# %%
def gradient(point, data):
    X = data[:, :-1]
    y = data[:, -1].reshape(-1, 1)
    Y = get_value(point, X)
    X = np.hstack((np.ones((X.shape[0], 1)), X))
    return 2 * X.T @ (Y - y)

# %%
class Model:
    def __init__(self):
        self.w = None
        self.loss_function = None

    def gen_model(self, data):
        self.w = np.random.uniform(0, 1, data.shape[1]).reshape(-1, 1)

    def cal_loss_function(self, data):
        self.loss_function = get_loss_function(self.w, data)
    
    def cal_value(self, inp):
        return get_value(self.w, inp)
    
    def show(self):
        print(f"w: {self.w.reshape(1, -1)}")
        print(f"loss_function: {self.loss_function}")

# %% [markdown]
# Giả sử hiện tại ta đang có lời giải $M^{(k)}$, để tối thiểu hóa hàm mất mát $J(x)$, ta đi ngược lại với $\vec{\triangledown}(M^{(k)})$.
# $M^{(k + 1)} = M^{(k)} - \alpha . \vec{\triangledown}(M^{(k)}) $ với $\alpha$ là hệ số học (learn_rate)

# %%
def train(model, data, learn_rate, max_inter):
    model.gen_model(data)
    history = []
    for i in range(max_inter):
        model.w -= learn_rate * gradient(model.w, data)
        model.cal_loss_function(data)
        history.append(model.loss_function)
        if model.loss_function < 1e-24:
            break
    return model, history

# %%
# Data cần được định dạng với cột cuối là kết quả
data = np.array([[1, 2], [3, 3], [5, 4], [7, 5], [9, 6]])

model = Model()
learn_rate = 0.0005
max_inter = 100000

model, history = train(model, data, learn_rate, max_inter)

for i in range(len(history)):
    print(f"Generation {i}, loss_function = {history[i]}")

print("w: ", model.w)
print("Loss function: ", model.loss_function)
# Out:
# Generation 0, loss_function = 41.36164702931079
# Generation 1, loss_function = 28.69531424210024
# Generation 2, loss_function = 19.944265738014444
# Generation 3, loss_function = 13.89816272511359
# Generation 4, loss_function = 9.720820800440492
# Generation 5, loss_function = 6.834546874261772
# Generation 6, loss_function = 4.840231246428968
# Generation 7, loss_function = 3.4621417749722534
# Generation 8, loss_function = 2.5097839309926693
# Generation 9, loss_function = 1.851551129147774
# Generation 10, loss_function = 1.39652058284872
# Generation 11, loss_function = 1.0818766422332393
# Generation 12, loss_function = 0.864221980192011
# Generation 13, loss_function = 0.7135747683994456
# Generation 14, loss_function = 0.6092215180218838
# Generation 15, loss_function = 0.5368519398634742
# Generation 16, loss_function = 0.48657951078135664
# Generation 17, loss_function = 0.45157394626426034
# Generation 18, loss_function = 0.427116419429168
# Generation 19, loss_function = 0.40994684201158327
# Generation 20, loss_function = 0.39781292165589766
# Generation 21, loss_function = 0.3891586200047817
# Generation 22, loss_function = 0.3829089183468193
# Generation 23, loss_function = 0.37832111907912386
# Generation 24, loss_function = 0.374882114638729
# Generation 25, loss_function = 0.37223741388950593
# Generation 26, loss_function = 0.3701421087204662
# Generation 27, loss_function = 0.3684269984351185
# Generation 28, loss_function = 0.3669751861743893
# Generation 29, loss_function = 0.36570591013294224
# Generation 30, loss_function = 0.3645633730631194
# Generation 31, loss_function = 0.3635090249360923
# Generation 32, loss_function = 0.36251623127901716
# Generation 33, loss_function = 0.3615665896995065
# Generation 34, loss_function = 0.36064738509006805
# Generation 35, loss_function = 0.35974983151014595
# Generation 36, loss_function = 0.35886785755858824
# Generation 37, loss_function = 0.35799726722628217
# Generation 38, loss_function = 0.3571351601560421
# Generation 39, loss_function = 0.35627953111868166
# Generation 40, loss_function = 0.3554289933038183
# Generation 41, loss_function = 0.35458258715032487
# Generation 42, loss_function = 0.3537396482733863
# Generation 43, loss_function = 0.3528997162195172
# Generation 44, loss_function = 0.3520624714283053
# Generation 45, loss_function = 0.3512276916812953
# Generation 46, loss_function = 0.35039522201389406
# Generation 47, loss_function = 0.3495649539284703
# Generation 48, loss_function = 0.34873681103333287
# Generation 49, loss_function = 0.3479107391211571
# Generation 50, loss_function = 0.347086699314475
# Generation 51, loss_function = 0.346264663330108
# Generation 52, loss_function = 0.34544461020750555
# Generation 53, loss_function = 0.3446265240484493
# Generation 54, loss_function = 0.3438103924554827
# Generation 55, loss_function = 0.3429962054530607
# Generation 56, loss_function = 0.34218395474220076
# Generation 57, loss_function = 0.3413736331855334
# Generation 58, loss_function = 0.3405652344515382
# Generation 59, loss_function = 0.33975875276874534
# Generation 60, loss_function = 0.3389541827559148
# Generation 61, loss_function = 0.338151519304704
# Generation 62, loss_function = 0.3373507574986014
# Generation 63, loss_function = 0.33655189255690754
# Generation 64, loss_function = 0.3357549197960316
# Generation 65, loss_function = 0.334959834602741
# Generation 66, loss_function = 0.3341666324156737
# Generation 67, loss_function = 0.3333753087125554
# Generation 68, loss_function = 0.3325858590013641
# Generation 69, loss_function = 0.33179827881421947
# Generation 70, loss_function = 0.33101256370314686
# Generation 71, loss_function = 0.3302287092371503
# Generation 72, loss_function = 0.3294467110001783
# Generation 73, loss_function = 0.3286665645897133
# Generation 74, loss_function = 0.32788826561578743
# Generation 75, loss_function = 0.32711180970029696
# Generation 76, loss_function = 0.3263371924765212
# Generation 77, loss_function = 0.32556440958877764
# Generation 78, loss_function = 0.3247934566921859
# Generation 79, loss_function = 0.3240243294524875
# Generation 80, loss_function = 0.32325702354591856
# Generation 81, loss_function = 0.32249153465911273
# Generation 82, loss_function = 0.3217278584890304
# Generation 83, loss_function = 0.32096599074289717
# Generation 84, loss_function = 0.32020592713815543
# Generation 85, loss_function = 0.31944766340242814
# Generation 86, loss_function = 0.3186911952734779
# Generation 87, loss_function = 0.3179365184991778
# Generation 88, loss_function = 0.3171836288374843
# Generation 89, loss_function = 0.3164325220564062
# Generation 90, loss_function = 0.31568319393397987
# Generation 91, loss_function = 0.31493564025824333
# Generation 92, loss_function = 0.31418985682721123
# Generation 93, loss_function = 0.31344583944885074
# Generation 94, loss_function = 0.312703583941058
# Generation 95, loss_function = 0.31196308613163215
# Generation 96, loss_function = 0.3112243418582543
# Generation 97, loss_function = 0.3104873469684623
# Generation 98, loss_function = 0.3097520973196263
# Generation 99, loss_function = 0.3090185887789282
# Generation 100, loss_function = 0.3082868172233351
# Generation 101, loss_function = 0.3075567785395802
# Generation 102, loss_function = 0.3068284686241344
# Generation 103, loss_function = 0.3061018833831879
# Generation 104, loss_function = 0.30537701873262485
# Generation 105, loss_function = 0.30465387059800025
# Generation 106, loss_function = 0.303932434914518
# Generation 107, loss_function = 0.30321270762700825
# Generation 108, loss_function = 0.3024946846899026
# Generation 109, loss_function = 0.30177836206721415
# Generation 110, loss_function = 0.3010637357325132
# Generation 111, loss_function = 0.30035080166890327
# Generation 112, loss_function = 0.2996395558690027
# Generation 113, loss_function = 0.29892999433491746
# Generation 114, loss_function = 0.29822211307822094
# Generation 115, loss_function = 0.29751590811993267
# Generation 116, loss_function = 0.296811375490493
# Generation 117, loss_function = 0.2961085112297446
# Generation 118, loss_function = 0.29540731138690474
# Generation 119, loss_function = 0.29470777202054843
# Generation 120, loss_function = 0.29400988919858523
# Generation 121, loss_function = 0.2933136589982336
# Generation 122, loss_function = 0.2926190775060024
# Generation 123, loss_function = 0.2919261408176679
# Generation 124, loss_function = 0.29123484503825225
# Generation 125, loss_function = 0.29054518628200054
# Generation 126, loss_function = 0.28985716067235934
# Generation 127, loss_function = 0.28917076434195527
# Generation 128, loss_function = 0.288485993432574
# Generation 129, loss_function = 0.28780284409513573
# Generation 130, loss_function = 0.2871213124896774
# Generation 131, loss_function = 0.2864413947853276
# Generation 132, loss_function = 0.2857630871602878
# Generation 133, loss_function = 0.2850863858018094
# Generation 134, loss_function = 0.2844112869061719
# Generation 135, loss_function = 0.28373778667866334
# Generation 136, loss_function = 0.28306588133355726
# Generation 137, loss_function = 0.2823955670940909
# Generation 138, loss_function = 0.28172684019244715
# Generation 139, loss_function = 0.28105969686972965
# Generation 140, loss_function = 0.2803941333759439
# Generation 141, loss_function = 0.2797301459699765
# Generation 142, loss_function = 0.27906773091957116
# Generation 143, loss_function = 0.2784068845013111
# Generation 144, loss_function = 0.27774760300059703
# Generation 145, loss_function = 0.2770898827116246
# Generation 146, loss_function = 0.2764337199373669
# Generation 147, loss_function = 0.27577911098955
# Generation 148, loss_function = 0.27512605218863556
# Generation 149, loss_function = 0.2744745398637965
# Generation 150, loss_function = 0.2738245703529012
# Generation 151, loss_function = 0.2731761400024877
# Generation 152, loss_function = 0.27252924516774657
# Generation 153, loss_function = 0.2718838822124999
# Generation 154, loss_function = 0.27124004750917996
# Generation 155, loss_function = 0.2705977374388103
# Generation 156, loss_function = 0.26995694839098144
# Generation 157, loss_function = 0.2693176767638363
# Generation 158, loss_function = 0.26867991896404675
# Generation 159, loss_function = 0.26804367140679336
# Generation 160, loss_function = 0.26740893051574643
# Generation 161, loss_function = 0.2667756927230437
# Generation 162, loss_function = 0.26614395446927314
# Generation 163, loss_function = 0.2655137122034511
# Generation 164, loss_function = 0.26488496238300335
# Generation 165, loss_function = 0.2642577014737435
# Generation 166, loss_function = 0.2636319259498556
# Generation 167, loss_function = 0.26300763229387103
# Generation 168, loss_function = 0.26238481699665417
# Generation 169, loss_function = 0.2617634765573753
# Generation 170, loss_function = 0.2611436074834979
# Generation 171, loss_function = 0.2605252062907541
# Generation 172, loss_function = 0.2599082695031279
# Generation 173, loss_function = 0.2592927936528342
# Generation 174, loss_function = 0.2586787752802996
# Generation 175, loss_function = 0.2580662109341445
# Generation 176, loss_function = 0.25745509717116005
# Generation 177, loss_function = 0.256845430556293
# Generation 178, loss_function = 0.25623720766262464
# Generation 179, loss_function = 0.2556304250713488
# Generation 180, loss_function = 0.25502507937175817
# Generation 181, loss_function = 0.25442116716122093
# Generation 182, loss_function = 0.25381868504516253
# Generation 183, loss_function = 0.2532176296370475
# Generation 184, loss_function = 0.25261799755836045
# Generation 185, loss_function = 0.25201978543858405
# Generation 186, loss_function = 0.251422989915186
# Generation 187, loss_function = 0.2508276076335939
# Generation 188, loss_function = 0.25023363524718056
# Generation 189, loss_function = 0.2496410694172417
# Generation 190, loss_function = 0.24904990681298336
# Generation 191, loss_function = 0.24846014411149547
# Generation 192, loss_function = 0.24787177799773713
# Generation 193, loss_function = 0.2472848051645194
# Generation 194, loss_function = 0.24669922231248367
# Generation 195, loss_function = 0.24611502615008413
# Generation 196, loss_function = 0.2455322133935702
# Generation 197, loss_function = 0.24495078076696802
# Generation 198, loss_function = 0.24437072500205942
# Generation 199, loss_function = 0.24379204283836753
# Generation 200, loss_function = 0.24321473102313473
# Generation 201, loss_function = 0.2426387863113079
# Generation 202, loss_function = 0.242064205465517
# Generation 203, loss_function = 0.24149098525605847
# Generation 204, loss_function = 0.240919122460877
# Generation 205, loss_function = 0.2403486138655482
# Generation 206, loss_function = 0.2397794562632579
# Generation 207, loss_function = 0.23921164645478682
# Generation 208, loss_function = 0.23864518124849154
# Generation 209, loss_function = 0.23808005746028682
# Generation 210, loss_function = 0.2375162719136262
# Generation 211, loss_function = 0.23695382143948732
# Generation 212, loss_function = 0.23639270287635056
# Generation 213, loss_function = 0.235832913070185
# Generation 214, loss_function = 0.23527444887442647
# Generation 215, loss_function = 0.23471730714996245
# Generation 216, loss_function = 0.23416148476511503
# Generation 217, loss_function = 0.23360697859562163
# Generation 218, loss_function = 0.23305378552461775
# Generation 219, loss_function = 0.23250190244262064
# Generation 220, loss_function = 0.23195132624751022
# Generation 221, loss_function = 0.23140205384451246
# Generation 222, loss_function = 0.23085408214618244
# Generation 223, loss_function = 0.2303074080723858
# Generation 224, loss_function = 0.22976202855028252
# Generation 225, loss_function = 0.22921794051430883
# Generation 226, loss_function = 0.2286751409061616
# Generation 227, loss_function = 0.2281336266747779
# Generation 228, loss_function = 0.22759339477632123
# Generation 229, loss_function = 0.22705444217416249
# Generation 230, loss_function = 0.2265167658388646
# Generation 231, loss_function = 0.22598036274816277
# Generation 232, loss_function = 0.22544522988694976
# Generation 233, loss_function = 0.22491136424725852
# Generation 234, loss_function = 0.2243787628282446
# Generation 235, loss_function = 0.22384742263617002
# Generation 236, loss_function = 0.22331734068438594
# Generation 237, loss_function = 0.22278851399331578
# Generation 238, loss_function = 0.22226093959043922
# Generation 239, loss_function = 0.22173461451027526
# Generation 240, loss_function = 0.22120953579436478
# Generation 241, loss_function = 0.22068570049125397
# Generation 242, loss_function = 0.22016310565647976
# Generation 243, loss_function = 0.21964174835254988
# Generation 244, loss_function = 0.21912162564892923
# Generation 245, loss_function = 0.2186027346220223
# Generation 246, loss_function = 0.2180850723551574
# Generation 247, loss_function = 0.21756863593856715
# Generation 248, loss_function = 0.21705342246937892
# Generation 249, loss_function = 0.21653942905158985
# Generation 250, loss_function = 0.21602665279605798
# Generation 251, loss_function = 0.21551509082048048
# Generation 252, loss_function = 0.21500474024938343
# Generation 253, loss_function = 0.21449559821409855
# Generation 254, loss_function = 0.21398766185275275
# Generation 255, loss_function = 0.21348092831024965
# Generation 256, loss_function = 0.2129753947382536
# Generation 257, loss_function = 0.2124710582951741
# Generation 258, loss_function = 0.21196791614614968
# Generation 259, loss_function = 0.21146596546303192
# Generation 260, loss_function = 0.2109652034243701
# Generation 261, loss_function = 0.21046562721539333
# Generation 262, loss_function = 0.20996723402799863
# Generation 263, loss_function = 0.20947002106073015
# Generation 264, loss_function = 0.2089739855187681
# Generation 265, loss_function = 0.20847912461390972
# Generation 266, loss_function = 0.2079854355645557
# Generation 267, loss_function = 0.20749291559569297
# Generation 268, loss_function = 0.2070015619388807
# Generation 269, loss_function = 0.20651137183223248
# Generation 270, loss_function = 0.2060223425204034
# Generation 271, loss_function = 0.20553447125457344
# Generation 272, loss_function = 0.2050477552924306
# Generation 273, loss_function = 0.2045621918981579
# Generation 274, loss_function = 0.20407777834241697
# Generation 275, loss_function = 0.2035945119023323
# Generation 276, loss_function = 0.20311238986147623
# Generation 277, loss_function = 0.20263140950985387
# Generation 278, loss_function = 0.20215156814388766
# Generation 279, loss_function = 0.20167286306640264
# Generation 280, loss_function = 0.2011952915866097
# Generation 281, loss_function = 0.2007188510200934
# Generation 282, loss_function = 0.20024353868879363
# Generation 283, loss_function = 0.1997693519209932
# Generation 284, loss_function = 0.19929628805130076
# Generation 285, loss_function = 0.19882434442063726
# Generation 286, loss_function = 0.19835351837622042
# Generation 287, loss_function = 0.19788380727154972
# Generation 288, loss_function = 0.1974152084663921
# Generation 289, loss_function = 0.19694771932676572
# Generation 290, loss_function = 0.19648133722492772
# Generation 291, loss_function = 0.19601605953935564
# Generation 292, loss_function = 0.19555188365473747
# Generation 293, loss_function = 0.19508880696195247
# Generation 294, loss_function = 0.19462682685805938
# Generation 295, loss_function = 0.19416594074628063
# Generation 296, loss_function = 0.19370614603598793
# Generation 297, loss_function = 0.19324744014268738
# Generation 298, loss_function = 0.1927898204880059
# Generation 299, loss_function = 0.19233328449967554
# Generation 300, loss_function = 0.19187782961152003
# Generation 301, loss_function = 0.19142345326343985
# Generation 302, loss_function = 0.1909701529013975
# Generation 303, loss_function = 0.19051792597740452
# Generation 304, loss_function = 0.1900667699495054
# Generation 305, loss_function = 0.18961668228176465
# Generation 306, loss_function = 0.1891676604442511
# Generation 307, loss_function = 0.1887197019130256
# Generation 308, loss_function = 0.18827280417012515
# Generation 309, loss_function = 0.18782696470355018
# Generation 310, loss_function = 0.1873821810072479
# Generation 311, loss_function = 0.18693845058110248
# Generation 312, loss_function = 0.18649577093091685
# Generation 313, loss_function = 0.1860541395684006
# Generation 314, loss_function = 0.18561355401115592
# Generation 315, loss_function = 0.1851740117826633
# Generation 316, loss_function = 0.1847355104122677
# Generation 317, loss_function = 0.18429804743516526
# Generation 318, loss_function = 0.18386162039238754
# Generation 319, loss_function = 0.18342622683079074
# Generation 320, loss_function = 0.18299186430303963
# Generation 321, loss_function = 0.1825585303675936
# Generation 322, loss_function = 0.18212622258869463
# Generation 323, loss_function = 0.18169493853635257
# Generation 324, loss_function = 0.1812646757863306
# Generation 325, loss_function = 0.18083543192013513
# Generation 326, loss_function = 0.1804072045249965
# Generation 327, loss_function = 0.17997999119386088
# Generation 328, loss_function = 0.17955378952537332
# Generation 329, loss_function = 0.1791285971238664
# Generation 330, loss_function = 0.1787044115993446
# Generation 331, loss_function = 0.17828123056747275
# Generation 332, loss_function = 0.17785905164956187
# Generation 333, loss_function = 0.1774378724725555
# Generation 334, loss_function = 0.17701769066901704
# Generation 335, loss_function = 0.17659850387711615
# Generation 336, loss_function = 0.1761803097406148
# Generation 337, loss_function = 0.17576310590885563
# Generation 338, loss_function = 0.17534689003674694
# Generation 339, loss_function = 0.17493165978475025
# Generation 340, loss_function = 0.1745174128188685
# Generation 341, loss_function = 0.17410414681062997
# Generation 342, loss_function = 0.17369185943707788
# Generation 343, loss_function = 0.17328054838075588
# Generation 344, loss_function = 0.1728702113296958
# Generation 345, loss_function = 0.17246084597740455
# Generation 346, loss_function = 0.17205245002285
# Generation 347, loss_function = 0.1716450211704501
# Generation 348, loss_function = 0.17123855713005784
# Generation 349, loss_function = 0.17083305561695028
# Generation 350, loss_function = 0.17042851435181444
# Generation 351, loss_function = 0.1700249310607343
# Generation 352, loss_function = 0.16962230347517965
# Generation 353, loss_function = 0.1692206293319916
# Generation 354, loss_function = 0.1688199063733704
# Generation 355, loss_function = 0.16842013234686384
# Generation 356, loss_function = 0.16802130500535215
# Generation 357, loss_function = 0.16762342210703854
# Generation 358, loss_function = 0.16722648141543323
# Generation 359, loss_function = 0.16683048069934373
# Generation 360, loss_function = 0.1664354177328606
# Generation 361, loss_function = 0.16604129029534642
# Generation 362, loss_function = 0.1656480961714204
# Generation 363, loss_function = 0.16525583315094966
# Generation 364, loss_function = 0.16486449902903405
# Generation 365, loss_function = 0.16447409160599533
# Generation 366, loss_function = 0.1640846086873643
# Generation 367, loss_function = 0.16369604808386745
# Generation 368, loss_function = 0.16330840761141616
# Generation 369, loss_function = 0.16292168509109414
# Generation 370, loss_function = 0.16253587834914485
# Generation 371, loss_function = 0.16215098521695817
# Generation 372, loss_function = 0.1617670035310613
# Generation 373, loss_function = 0.16138393113310284
# Generation 374, loss_function = 0.16100176586984383
# Generation 375, loss_function = 0.16062050559314317
# Generation 376, loss_function = 0.1602401481599473
# Generation 377, loss_function = 0.15986069143227763
# Generation 378, loss_function = 0.1594821332772183
# Generation 379, loss_function = 0.1591044715669034
# Generation 380, loss_function = 0.15872770417850754
# Generation 381, loss_function = 0.15835182899423145
# Generation 382, loss_function = 0.15797684390128997
# Generation 383, loss_function = 0.15760274679190325
# Generation 384, loss_function = 0.15722953556328084
# Generation 385, loss_function = 0.15685720811761258
# Generation 386, loss_function = 0.15648576236205675
# Generation 387, loss_function = 0.156115196208726
# Generation 388, loss_function = 0.15574550757467803
# Generation 389, loss_function = 0.1553766943819033
# Generation 390, loss_function = 0.15500875455731306
# Generation 391, loss_function = 0.15464168603272732
# Generation 392, loss_function = 0.15427548674486372
# Generation 393, loss_function = 0.15391015463532662
# Generation 394, loss_function = 0.15354568765059357
# Generation 395, loss_function = 0.15318208374200568
# Generation 396, loss_function = 0.1528193408657551
# Generation 397, loss_function = 0.15245745698287394
# Generation 398, loss_function = 0.15209643005922296
# Generation 399, loss_function = 0.15173625806547977
# Generation 400, loss_function = 0.15137693897712665
# Generation 401, loss_function = 0.15101847077444147
# Generation 402, loss_function = 0.15066085144248356
# Generation 403, loss_function = 0.15030407897108558
# Generation 404, loss_function = 0.14994815135483747
# Generation 405, loss_function = 0.1495930665930807
# Generation 406, loss_function = 0.14923882268989355
# Generation 407, loss_function = 0.14888541765408028
# Generation 408, loss_function = 0.14853284949916104
# Generation 409, loss_function = 0.1481811162433595
# Generation 410, loss_function = 0.14783021590959292
# Generation 411, loss_function = 0.14748014652546
# Generation 412, loss_function = 0.1471309061232297
# Generation 413, loss_function = 0.1467824927398318
# Generation 414, loss_function = 0.14643490441684387
# Generation 415, loss_function = 0.14608813920048097
# Generation 416, loss_function = 0.14574219514158657
# Generation 417, loss_function = 0.1453970702956173
# Generation 418, loss_function = 0.14505276272263573
# Generation 419, loss_function = 0.14470927048729867
# Generation 420, loss_function = 0.1443665916588458
# Generation 421, loss_function = 0.1440247243110885
# Generation 422, loss_function = 0.14368366652239953
# Generation 423, loss_function = 0.14334341637570264
# Generation 424, loss_function = 0.14300397195846046
# Generation 425, loss_function = 0.14266533136266601
# Generation 426, loss_function = 0.1423274926848289
# Generation 427, loss_function = 0.1419904540259672
# Generation 428, loss_function = 0.14165421349159607
# Generation 429, loss_function = 0.14131876919171632
# Generation 430, loss_function = 0.14098411924080478
# Generation 431, loss_function = 0.14065026175780304
# Generation 432, loss_function = 0.1403171948661073
# Generation 433, loss_function = 0.1399849166935575
# Generation 434, loss_function = 0.1396534253724274
# Generation 435, loss_function = 0.13932271903941276
# Generation 436, loss_function = 0.13899279583562252
# Generation 437, loss_function = 0.1386636539065678
# Generation 438, loss_function = 0.13833529140214976
# Generation 439, loss_function = 0.13800770647665223
# Generation 440, loss_function = 0.13768089728872915
# Generation 441, loss_function = 0.1373548620013949
# Generation 442, loss_function = 0.1370295987820142
# Generation 443, loss_function = 0.13670510580229056
# Generation 444, loss_function = 0.136381381238259
# Generation 445, loss_function = 0.13605842327027148
# Generation 446, loss_function = 0.13573623008299054
# Generation 447, loss_function = 0.13541479986537688
# Generation 448, loss_function = 0.13509413081067972
# Generation 449, loss_function = 0.13477422111642784
# Generation 450, loss_function = 0.13445506898441617
# Generation 451, loss_function = 0.1341366726207003
# Generation 452, loss_function = 0.13381903023558253
# Generation 453, loss_function = 0.1335021400436036
# Generation 454, loss_function = 0.1331860002635326
# Generation 455, loss_function = 0.13287060911835635
# Generation 456, loss_function = 0.13255596483526935
# Generation 457, loss_function = 0.13224206564566485
# Generation 458, loss_function = 0.1319289097851247
# Generation 459, loss_function = 0.13161649549340668
# Generation 460, loss_function = 0.1313048210144404
# Generation 461, loss_function = 0.13099388459631078
# Generation 462, loss_function = 0.13068368449125328
# Generation 463, loss_function = 0.13037421895564152
# Generation 464, loss_function = 0.1300654862499776
# Generation 465, loss_function = 0.12975748463888384
# Generation 466, loss_function = 0.12945021239109109
# Generation 467, loss_function = 0.12914366777943098
# Generation 468, loss_function = 0.12883784908082413
# Generation 469, loss_function = 0.12853275457627178
# Generation 470, loss_function = 0.12822838255084698
# Generation 471, loss_function = 0.1279247312936816
# Generation 472, loss_function = 0.1276217990979607
# Generation 473, loss_function = 0.1273195842609111
# Generation 474, loss_function = 0.1270180850837905
# Generation 475, loss_function = 0.1267172998718803
# Generation 476, loss_function = 0.12641722693447582
# Generation 477, loss_function = 0.1261178645848741
# Generation 478, loss_function = 0.12581921114036831
# Generation 479, loss_function = 0.12552126492223573
# Generation 480, loss_function = 0.1252240242557279
# Generation 481, loss_function = 0.12492748747006388
# Generation 482, loss_function = 0.12463165289841782
# Generation 483, loss_function = 0.12433651887791182
# Generation 484, loss_function = 0.12404208374960596
# Generation 485, loss_function = 0.12374834585848797
# Generation 486, loss_function = 0.123455303553465
# Generation 487, loss_function = 0.12316295518735458
# Generation 488, loss_function = 0.12287129911687424
# Generation 489, loss_function = 0.12258033370263333
# Generation 490, loss_function = 0.1222900573091229
# Generation 491, loss_function = 0.12200046830470705
# Generation 492, loss_function = 0.12171156506161428
# Generation 493, loss_function = 0.12142334595592719
# Generation 494, loss_function = 0.12113580936757398
# Generation 495, loss_function = 0.12084895368031918
# Generation 496, loss_function = 0.12056277728175445
# Generation 497, loss_function = 0.12027727856329122
# Generation 498, loss_function = 0.11999245592014708
# Generation 499, loss_function = 0.1197083077513435
# Generation 500, loss_function = 0.11942483245969045
# Generation 501, loss_function = 0.11914202845178078
# Generation 502, loss_function = 0.11885989413798141
# Generation 503, loss_function = 0.11857842793242271
# Generation 504, loss_function = 0.11829762825299063
# Generation 505, loss_function = 0.11801749352131795
# Generation 506, loss_function = 0.11773802216277482
# Generation 507, loss_function = 0.11745921260646101
# Generation 508, loss_function = 0.11718106328519479
# Generation 509, loss_function = 0.11690357263550619
# Generation 510, loss_function = 0.11662673909762881
# Generation 511, loss_function = 0.11635056111548794
# Generation 512, loss_function = 0.11607503713669498
# Generation 513, loss_function = 0.11580016561253682
# Generation 514, loss_function = 0.11552594499796864
# Generation 515, loss_function = 0.11525237375160309
# Generation 516, loss_function = 0.11497945033570428
# Generation 517, loss_function = 0.11470717321617697
# Generation 518, loss_function = 0.11443554086255867
# Generation 519, loss_function = 0.11416455174801117
# Generation 520, loss_function = 0.1138942043493121
# Generation 521, loss_function = 0.11362449714684629
# Generation 522, loss_function = 0.11335542862459673
# Generation 523, loss_function = 0.11308699727013657
# Generation 524, loss_function = 0.1128192015746203
# Generation 525, loss_function = 0.11255204003277579
# Generation 526, loss_function = 0.11228551114289531
# Generation 527, loss_function = 0.11201961340682678
# Generation 528, loss_function = 0.1117543453299665
# Generation 529, loss_function = 0.11148970542125027
# Generation 530, loss_function = 0.11122569219314338
# Generation 531, loss_function = 0.11096230416163559
# Generation 532, loss_function = 0.11069953984622896
# Generation 533, loss_function = 0.11043739776993332
# Generation 534, loss_function = 0.1101758764592545
# Generation 535, loss_function = 0.10991497444418884
# Generation 536, loss_function = 0.10965469025821294
# Generation 537, loss_function = 0.10939502243827631
# Generation 538, loss_function = 0.10913596952479326
# Generation 539, loss_function = 0.1088775300616348
# Generation 540, loss_function = 0.10861970259611904
# Generation 541, loss_function = 0.1083624856790051
# Generation 542, loss_function = 0.10810587786448385
# Generation 543, loss_function = 0.10784987771016935
# Generation 544, loss_function = 0.10759448377709202
# Generation 545, loss_function = 0.10733969462968922
# Generation 546, loss_function = 0.10708550883579829
# Generation 547, loss_function = 0.10683192496664756
# Generation 548, loss_function = 0.1065789415968491
# Generation 549, loss_function = 0.10632655730439029
# Generation 550, loss_function = 0.10607477067062572
# Generation 551, loss_function = 0.10582358028026995
# Generation 552, loss_function = 0.10557298472138822
# Generation 553, loss_function = 0.10532298258539008
# Generation 554, loss_function = 0.10507357246701943
# Generation 555, loss_function = 0.10482475296434965
# Generation 556, loss_function = 0.10457652267877289
# Generation 557, loss_function = 0.10432888021499312
# Generation 558, loss_function = 0.10408182418101927
# Generation 559, loss_function = 0.10383535318815551
# Generation 560, loss_function = 0.10358946585099497
# Generation 561, loss_function = 0.10334416078741246
# Generation 562, loss_function = 0.1030994366185542
# Generation 563, loss_function = 0.10285529196883242
# Generation 564, loss_function = 0.10261172546591688
# Generation 565, loss_function = 0.10236873574072644
# Generation 566, loss_function = 0.10212632142742324
# Generation 567, loss_function = 0.10188448116340201
# Generation 568, loss_function = 0.1016432135892856
# Generation 569, loss_function = 0.1014025173489157
# Generation 570, loss_function = 0.10116239108934506
# Generation 571, loss_function = 0.10092283346083064
# Generation 572, loss_function = 0.10068384311682552
# Generation 573, loss_function = 0.10044541871397113
# Generation 574, loss_function = 0.10020755891209045
# Generation 575, loss_function = 0.09997026237418048
# Generation 576, loss_function = 0.09973352776640354
# Generation 577, loss_function = 0.09949735375808062
# Generation 578, loss_function = 0.09926173902168421
# Generation 579, loss_function = 0.09902668223283018
# Generation 580, loss_function = 0.09879218207027071
# Generation 581, loss_function = 0.098558237215887
# Generation 582, loss_function = 0.09832484635468107
# Generation 583, loss_function = 0.09809200817476899
# Generation 584, loss_function = 0.09785972136737417
# Generation 585, loss_function = 0.0976279846268182
# Generation 586, loss_function = 0.09739679665051612
# Generation 587, loss_function = 0.09716615613896581
# Generation 588, loss_function = 0.0969360617957435
# Generation 589, loss_function = 0.09670651232749455
# Generation 590, loss_function = 0.09647750644392855
# Generation 591, loss_function = 0.09624904285780912
# Generation 592, loss_function = 0.09602112028494864
# Generation 593, loss_function = 0.09579373744420057
# Generation 594, loss_function = 0.09556689305745206
# Generation 595, loss_function = 0.09534058584961703
# Generation 596, loss_function = 0.09511481454862891
# Generation 597, loss_function = 0.09488957788543288
# Generation 598, loss_function = 0.09466487459398051
# Generation 599, loss_function = 0.09444070341122031
# Generation 600, loss_function = 0.09421706307709204
# Generation 601, loss_function = 0.09399395233451965
# Generation 602, loss_function = 0.09377136992940349
# Generation 603, loss_function = 0.09354931461061418
# Generation 604, loss_function = 0.09332778512998438
# Generation 605, loss_function = 0.09310678024230346
# Generation 606, loss_function = 0.0928862987053086
# Generation 607, loss_function = 0.09266633927967907
# Generation 608, loss_function = 0.09244690072902896
# Generation 609, loss_function = 0.09222798181989988
# Generation 610, loss_function = 0.09200958132175495
# Generation 611, loss_function = 0.09179169800697057
# Generation 612, loss_function = 0.09157433065083083
# Generation 613, loss_function = 0.09135747803151972
# Generation 614, loss_function = 0.09114113893011426
# Generation 615, loss_function = 0.0909253121305782
# Generation 616, loss_function = 0.09070999641975562
# Generation 617, loss_function = 0.09049519058736213
# Generation 618, loss_function = 0.09028089342598025
# Generation 619, loss_function = 0.09006710373105098
# Generation 620, loss_function = 0.08985382030086839
# Generation 621, loss_function = 0.08964104193657287
# Generation 622, loss_function = 0.08942876744214182
# Generation 623, loss_function = 0.08921699562438705
# Generation 624, loss_function = 0.08900572529294437
# Generation 625, loss_function = 0.08879495526026941
# Generation 626, loss_function = 0.0885846843416294
# Generation 627, loss_function = 0.08837491135509669
# Generation 628, loss_function = 0.08816563512154345
# Generation 629, loss_function = 0.08795685446463376
# Generation 630, loss_function = 0.08774856821081715
# Generation 631, loss_function = 0.08754077518932211
# Generation 632, loss_function = 0.08733347423214972
# Generation 633, loss_function = 0.08712666417406688
# Generation 634, loss_function = 0.08692034385259999
# Generation 635, loss_function = 0.08671451210802808
# Generation 636, loss_function = 0.08650916778337653
# Generation 637, loss_function = 0.08630430972441007
# Generation 638, loss_function = 0.08609993677962766
# Generation 639, loss_function = 0.08589604780025452
# Generation 640, loss_function = 0.08569264164023566
# Generation 641, loss_function = 0.08548971715623122
# Generation 642, loss_function = 0.08528727320760751
# Generation 643, loss_function = 0.08508530865643325
# Generation 644, loss_function = 0.08488382236747091
# Generation 645, loss_function = 0.08468281320817155
# Generation 646, loss_function = 0.08448228004866748
# Generation 647, loss_function = 0.08428222176176868
# Generation 648, loss_function = 0.08408263722295176
# Generation 649, loss_function = 0.08388352531035806
# Generation 650, loss_function = 0.08368488490478423
# Generation 651, loss_function = 0.08348671488967861
# Generation 652, loss_function = 0.08328901415113263
# Generation 653, loss_function = 0.08309178157787608
# Generation 654, loss_function = 0.08289501606126981
# Generation 655, loss_function = 0.0826987164952998
# Generation 656, loss_function = 0.08250288177657206
# Generation 657, loss_function = 0.08230751080430476
# Generation 658, loss_function = 0.08211260248032311
# Generation 659, loss_function = 0.08191815570905261
# Generation 660, loss_function = 0.08172416939751323
# Generation 661, loss_function = 0.0815306424553128
# Generation 662, loss_function = 0.08133757379464229
# Generation 663, loss_function = 0.08114496233026772
# Generation 664, loss_function = 0.080952806979525
# Generation 665, loss_function = 0.08076110666231423
# Generation 666, loss_function = 0.08056986030109356
# Generation 667, loss_function = 0.0803790668208721
# Generation 668, loss_function = 0.08018872514920444
# Generation 669, loss_function = 0.07999883421618617
# Generation 670, loss_function = 0.07980939295444445
# Generation 671, loss_function = 0.0796204002991359
# Generation 672, loss_function = 0.07943185518793769
# Generation 673, loss_function = 0.07924375656104253
# Generation 674, loss_function = 0.07905610336115361
# Generation 675, loss_function = 0.07886889453347698
# Generation 676, loss_function = 0.0786821290257172
# Generation 677, loss_function = 0.07849580578807022
# Generation 678, loss_function = 0.07830992377321824
# Generation 679, loss_function = 0.07812448193632385
# Generation 680, loss_function = 0.07793947923502295
# Generation 681, loss_function = 0.07775491462942055
# Generation 682, loss_function = 0.07757078708208426
# Generation 683, loss_function = 0.07738709555803784
# Generation 684, loss_function = 0.07720383902475648
# Generation 685, loss_function = 0.0770210164521597
# Generation 686, loss_function = 0.07683862681260718
# Generation 687, loss_function = 0.07665666908089178
# Generation 688, loss_function = 0.0764751422342336
# Generation 689, loss_function = 0.0762940452522756
# Generation 690, loss_function = 0.07611337711707634
# Generation 691, loss_function = 0.07593313681310501
# Generation 692, loss_function = 0.07575332332723617
# Generation 693, loss_function = 0.07557393564874273
# Generation 694, loss_function = 0.07539497276929147
# Generation 695, loss_function = 0.07521643368293707
# Generation 696, loss_function = 0.07503831738611598
# Generation 697, loss_function = 0.07486062287764134
# Generation 698, loss_function = 0.07468334915869757
# Generation 699, loss_function = 0.07450649523283305
# Generation 700, loss_function = 0.07433006010595727
# Generation 701, loss_function = 0.07415404278633315
# Generation 702, loss_function = 0.0739784422845719
# Generation 703, loss_function = 0.07380325761362826
# Generation 704, loss_function = 0.07362848778879333
# Generation 705, loss_function = 0.07345413182769103
# Generation 706, loss_function = 0.07328018875027101
# Generation 707, loss_function = 0.07310665757880416
# Generation 708, loss_function = 0.07293353733787677
# Generation 709, loss_function = 0.07276082705438423
# Generation 710, loss_function = 0.07258852575752674
# Generation 711, loss_function = 0.0724166324788034
# Generation 712, loss_function = 0.07224514625200688
# Generation 713, loss_function = 0.07207406611321786
# Generation 714, loss_function = 0.07190339110079891
# Generation 715, loss_function = 0.07173312025539123
# Generation 716, loss_function = 0.07156325261990651
# Generation 717, loss_function = 0.0713937872395235
# Generation 718, loss_function = 0.07122472316168196
# Generation 719, loss_function = 0.07105605943607715
# Generation 720, loss_function = 0.0708877951146553
# Generation 721, loss_function = 0.07071992925160647
# Generation 722, loss_function = 0.07055246090336166
# Generation 723, loss_function = 0.07038538912858606
# Generation 724, loss_function = 0.07021871298817302
# Generation 725, loss_function = 0.07005243154524103
# Generation 726, loss_function = 0.06988654386512651
# Generation 727, loss_function = 0.06972104901537911
# Generation 728, loss_function = 0.06955594606575702
# Generation 729, loss_function = 0.06939123408822145
# Generation 730, loss_function = 0.06922691215692975
# Generation 731, loss_function = 0.06906297934823354
# Generation 732, loss_function = 0.06889943474067103
# Generation 733, loss_function = 0.06873627741496187
# Generation 734, loss_function = 0.06857350645400369
# Generation 735, loss_function = 0.06841112094286528
# Generation 736, loss_function = 0.06824911996878165
# Generation 737, loss_function = 0.06808750262115043
# Generation 738, loss_function = 0.06792626799152392
# Generation 739, loss_function = 0.06776541517360743
# Generation 740, loss_function = 0.06760494326325134
# Generation 741, loss_function = 0.06744485135844763
# Generation 742, loss_function = 0.06728513855932386
# Generation 743, loss_function = 0.06712580396813876
# Generation 744, loss_function = 0.06696684668927685
# Generation 745, loss_function = 0.06680826582924336
# Generation 746, loss_function = 0.0666500604966601
# Generation 747, loss_function = 0.06649222980225877
# Generation 748, loss_function = 0.06633477285887754
# Generation 749, loss_function = 0.06617768878145515
# Generation 750, loss_function = 0.06602097668702614
# Generation 751, loss_function = 0.06586463569471628
# Generation 752, loss_function = 0.06570866492573701
# Generation 753, loss_function = 0.06555306350338068
# Generation 754, loss_function = 0.06539783055301616
# Generation 755, loss_function = 0.06524296520208309
# Generation 756, loss_function = 0.06508846658008768
# Generation 757, loss_function = 0.06493433381859733
# Generation 758, loss_function = 0.06478056605123605
# Generation 759, loss_function = 0.06462716241367918
# Generation 760, loss_function = 0.06447412204364908
# Generation 761, loss_function = 0.06432144408090985
# Generation 762, loss_function = 0.06416912766726342
# Generation 763, loss_function = 0.06401717194654273
# Generation 764, loss_function = 0.063865576064609
# Generation 765, loss_function = 0.0637143391693458
# Generation 766, loss_function = 0.06356346041065476
# Generation 767, loss_function = 0.0634129389404505
# Generation 768, loss_function = 0.06326277391265574
# Generation 769, loss_function = 0.06311296448319732
# Generation 770, loss_function = 0.06296350980999996
# Generation 771, loss_function = 0.06281440905298336
# Generation 772, loss_function = 0.06266566137405626
# Generation 773, loss_function = 0.06251726593711154
# Generation 774, loss_function = 0.06236922190802296
# Generation 775, loss_function = 0.06222152845463883
# Generation 776, loss_function = 0.06207418474677836
# Generation 777, loss_function = 0.061927189956226585
# Generation 778, loss_function = 0.061780543256729555
# Generation 779, loss_function = 0.06163424382399045
# Generation 780, loss_function = 0.06148829083566375
# Generation 781, loss_function = 0.061342683471351876
# Generation 782, loss_function = 0.0611974209126
# Generation 783, loss_function = 0.06105250234289083
# Generation 784, loss_function = 0.060907926947641106
# Generation 785, loss_function = 0.060763693914196844
# Generation 786, loss_function = 0.060619802431827643
# Generation 787, loss_function = 0.060476251691723396
# Generation 788, loss_function = 0.06033304088698953
# Generation 789, loss_function = 0.06019016921264199
# Generation 790, loss_function = 0.0600476358656027
# Generation 791, loss_function = 0.059905440044695724
# Generation 792, loss_function = 0.059763580950642006
# Generation 793, loss_function = 0.059622057786055914
# Generation 794, loss_function = 0.059480869755439356
# Generation 795, loss_function = 0.059340016065178074
# Generation 796, loss_function = 0.05919949592353741
# Generation 797, loss_function = 0.05905930854065755
# Generation 798, loss_function = 0.05891945312854879
# Generation 799, loss_function = 0.05877992890108775
# Generation 800, loss_function = 0.05864073507401291
# Generation 801, loss_function = 0.05850187086491882
# Generation 802, loss_function = 0.05836333549325409
# Generation 803, loss_function = 0.05822512818031476
# Generation 804, loss_function = 0.05808724814924166
# Generation 805, loss_function = 0.05794969462501477
# Generation 806, loss_function = 0.05781246683444939
# Generation 807, loss_function = 0.05767556400619176
# Generation 808, loss_function = 0.057538985370714876
# Generation 809, loss_function = 0.057402730160314205
# Generation 810, loss_function = 0.05726679760910221
# Generation 811, loss_function = 0.057131186953006466
# Generation 812, loss_function = 0.056995897429762514
# Generation 813, loss_function = 0.056860928278912135
# Generation 814, loss_function = 0.056726278741797045
# Generation 815, loss_function = 0.056591948061556235
# Generation 816, loss_function = 0.056457935483120156
# Generation 817, loss_function = 0.05632424025320796
# Generation 818, loss_function = 0.05619086162032257
# Generation 819, loss_function = 0.056057798834745654
# Generation 820, loss_function = 0.05592505114853559
# Generation 821, loss_function = 0.05579261781552105
# Generation 822, loss_function = 0.0556604980912976
# Generation 823, loss_function = 0.05552869123322417
# Generation 824, loss_function = 0.055397196500418
# Generation 825, loss_function = 0.05526601315375035
# Generation 826, loss_function = 0.05513514045584373
# Generation 827, loss_function = 0.055004577671065716
# Generation 828, loss_function = 0.05487432406552706
# Generation 829, loss_function = 0.05474437890707506
# Generation 830, loss_function = 0.05461474146529201
# Generation 831, loss_function = 0.05448541101148928
# Generation 832, loss_function = 0.054356386818703785
# Generation 833, loss_function = 0.05422766816169409
# Generation 834, loss_function = 0.0540992543169361
# Generation 835, loss_function = 0.05397114456261935
# Generation 836, loss_function = 0.053843338178641904
# Generation 837, loss_function = 0.05371583444660802
# Generation 838, loss_function = 0.05358863264982232
# Generation 839, loss_function = 0.053461732073287034
# Generation 840, loss_function = 0.053335132003697536
# Generation 841, loss_function = 0.05320883172943804
# Generation 842, loss_function = 0.0530828305405785
# Generation 843, loss_function = 0.052957127728869645
# Generation 844, loss_function = 0.05283172258773889
# Generation 845, loss_function = 0.05270661441228805
# Generation 846, loss_function = 0.0525818024992869
# Generation 847, loss_function = 0.05245728614717122
# Generation 848, loss_function = 0.052333064656038104
# Generation 849, loss_function = 0.052209137327641736
# Generation 850, loss_function = 0.05208550346538993
# Generation 851, loss_function = 0.051962162374340266
# Generation 852, loss_function = 0.05183911336119576
# Generation 853, loss_function = 0.05171635573430114
# Generation 854, loss_function = 0.051593888803639326
# Generation 855, loss_function = 0.05147171188082706
# Generation 856, loss_function = 0.051349824279110896
# Generation 857, loss_function = 0.05122822531336404
# Generation 858, loss_function = 0.0511069143000822
# Generation 859, loss_function = 0.050985890557378954
# Generation 860, loss_function = 0.05086515340498379
# Generation 861, loss_function = 0.05074470216423598
# Generation 862, loss_function = 0.05062453615808274
# Generation 863, loss_function = 0.050504654711073634
# Generation 864, loss_function = 0.05038505714935888
# Generation 865, loss_function = 0.050265742800683647
# Generation 866, loss_function = 0.05014671099438503
# Generation 867, loss_function = 0.050027961061388466
# Generation 868, loss_function = 0.04990949233420418
# Generation 869, loss_function = 0.049791304146922365
# Generation 870, loss_function = 0.04967339583521063
# Generation 871, loss_function = 0.049555766736309334
# Generation 872, loss_function = 0.049438416189028535
# Generation 873, loss_function = 0.04932134353374395
# Generation 874, loss_function = 0.04920454811239371
# Generation 875, loss_function = 0.04908802926847374
# Generation 876, loss_function = 0.048971786347034384
# Generation 877, loss_function = 0.048855818694677755
# Generation 878, loss_function = 0.04874012565955266
# Generation 879, loss_function = 0.04862470659135197
# Generation 880, loss_function = 0.04850956084130787
# Generation 881, loss_function = 0.0483946877621893
# Generation 882, loss_function = 0.04828008670829802
# Generation 883, loss_function = 0.04816575703546435
# Generation 884, loss_function = 0.048051698101044565
# Generation 885, loss_function = 0.04793790926391604
# Generation 886, loss_function = 0.047824389884475405
# Generation 887, loss_function = 0.047711139324632904
# Generation 888, loss_function = 0.047598156947810215
# Generation 889, loss_function = 0.04748544211893682
# Generation 890, loss_function = 0.04737299420444499
# Generation 891, loss_function = 0.04726081257226898
# Generation 892, loss_function = 0.0471488965918383
# Generation 893, loss_function = 0.04703724563407633
# Generation 894, loss_function = 0.04692585907139621
# Generation 895, loss_function = 0.046814736277696944
# Generation 896, loss_function = 0.046703876628360105
# Generation 897, loss_function = 0.0465932795002473
# Generation 898, loss_function = 0.046482944271694415
# Generation 899, loss_function = 0.046372870322510557
# Generation 900, loss_function = 0.04626305703397264
# Generation 901, loss_function = 0.046153503788823644
# Generation 902, loss_function = 0.04604420997126707
# Generation 903, loss_function = 0.04593517496696613
# Generation 904, loss_function = 0.04582639816303738
# Generation 905, loss_function = 0.04571787894804973
# Generation 906, loss_function = 0.0456096167120194
# Generation 907, loss_function = 0.04550161084640739
# Generation 908, loss_function = 0.04539386074411565
# Generation 909, loss_function = 0.045286365799483794
# Generation 910, loss_function = 0.045179125408285524
# Generation 911, loss_function = 0.045072138967725786
# Generation 912, loss_function = 0.044965405876436396
# Generation 913, loss_function = 0.04485892553447391
# Generation 914, loss_function = 0.044752697343314767
# Generation 915, loss_function = 0.04464672070585368
# Generation 916, loss_function = 0.04454099502639834
# Generation 917, loss_function = 0.044435519710667656
# Generation 918, loss_function = 0.04433029416578811
# Generation 919, loss_function = 0.04422531780028967
# Generation 920, loss_function = 0.04412059002410275
# Generation 921, loss_function = 0.0440161102485557
# Generation 922, loss_function = 0.04391187788637004
# Generation 923, loss_function = 0.04380789235165907
# Generation 924, loss_function = 0.043704153059922715
# Generation 925, loss_function = 0.043600659428044884
# Generation 926, loss_function = 0.0434974108742911
# Generation 927, loss_function = 0.04339440681830379
# Generation 928, loss_function = 0.04329164668110027
# ...
# Generation 22637, loss_function = 1.933367374305466e-24
# Generation 22638, loss_function = 1.9275208796178403e-24
# Generation 22639, loss_function = 1.9234631763366097e-24
# Generation 22640, loss_function = 1.9180442935634203e-24
# Generation 22641, loss_function = 1.913159864053518e-24
# Generation 22642, loss_function = 1.908591373336157e-24
# Generation 22643, loss_function = 1.904554180438462e-24
# Generation 22644, loss_function = 1.89916211893605e-24
# Generation 22645, loss_function = 1.8943013552533046e-24
# Generation 22646, loss_function = 1.8897565303631e-24
# Generation 22647, loss_function = 1.885739847848941e-24
# Generation 22648, loss_function = 1.880664316784749e-24
# Generation 22649, loss_function = 1.8763961848570507e-24
# Generation 22650, loss_function = 1.8711506542677836e-24
# Generation 22651, loss_function = 1.8670473942692765e-24
# Generation 22652, loss_function = 1.861968313331011e-24
# Generation 22653, loss_function = 1.857722269508659e-24
# Generation 22654, loss_function = 1.8527905083444434e-24
# Generation 22655, loss_function = 1.847319955181962e-24
# Generation 22656, loss_function = 1.8435000934636556e-24
# Generation 22657, loss_function = 1.838042950936563e-24
# Generation 22658, loss_function = 1.8342333444100244e-24
# Generation 22659, loss_function = 1.8287896125183205e-24
# Generation 22660, loss_function = 1.8249902611835498e-24
# Generation 22661, loss_function = 1.8195599399272346e-24
# Generation 22662, loss_function = 1.8157708437842318e-24
# Generation 22663, loss_function = 1.8112735477635668e-24
# Generation 22664, loss_function = 1.806526380051173e-24
# Generation 22665, loss_function = 1.8046899118638185e-24
# Generation 22666, loss_function = 1.799951816051835e-24
# Generation 22667, loss_function = 1.7954750304147056e-24
# Generation 22668, loss_function = 1.790749161946753e-24
# Generation 22669, loss_function = 1.7889205823684505e-24
# Generation 22670, loss_function = 1.7842037858009078e-24
# Generation 22671, loss_function = 1.7797475105473143e-24
# Generation 22672, loss_function = 1.7750429413238025e-24
# Generation 22673, loss_function = 1.7732222503545524e-24
# Generation 22674, loss_function = 1.7685267530314506e-24
# Generation 22675, loss_function = 1.764090988161393e-24
# Generation 22676, loss_function = 1.759407718182322e-24
# Generation 22677, loss_function = 1.757594915822124e-24
# Generation 22678, loss_function = 1.7529207177434633e-24
# Generation 22679, loss_function = 1.7485054632569413e-24
# Generation 22680, loss_function = 1.7438434925223115e-24
# Generation 22681, loss_function = 1.7420385787711658e-24
# Generation 22682, loss_function = 1.737385679936946e-24
# Generation 22683, loss_function = 1.7329909358339597e-24
# Generation 22684, loss_function = 1.7283502643437708e-24
# Generation 22685, loss_function = 1.7265532392016773e-24
# Generation 22686, loss_function = 1.7219216396118985e-24
# Generation 22687, loss_function = 1.717547405892448e-24
# Generation 22688, loss_function = 1.7129280336467e-24
# Generation 22689, loss_function = 1.7111388971136588e-24
# Generation 22690, loss_function = 1.706528596768321e-24
# Generation 22691, loss_function = 1.702174873432406e-24
# Generation 22692, loss_function = 1.697576800431099e-24
# Generation 22693, loss_function = 1.69579555250711e-24
# Generation 22694, loss_function = 1.691206551406213e-24
# Generation 22695, loss_function = 1.686873338453834e-24
# Generation 22696, loss_function = 1.683213221068835e-24
# Generation 22697, loss_function = 1.6793638263703893e-24
# Generation 22698, loss_function = 1.6756661887885855e-24
# Generation 22699, loss_function = 1.67288806719943e-24
# Generation 22700, loss_function = 1.667997671928932e-24
# Generation 22701, loss_function = 1.6646369272574642e-24
# Generation 22702, loss_function = 1.6603368464631045e-24
# Generation 22703, loss_function = 1.656567866273185e-24
# Generation 22704, loss_function = 1.6532656945239297e-24
# Generation 22705, loss_function = 1.6493592553212752e-24
# Generation 22706, loss_function = 1.6456932707832934e-24
# Generation 22707, loss_function = 1.641887953687927e-24
# Generation 22708, loss_function = 1.637809000466062e-24
# Generation 22709, loss_function = 1.6342951674751748e-24
# Generation 22710, loss_function = 1.6306477211684657e-24
# Generation 22711, loss_function = 1.6277626103190396e-24
# Generation 22712, loss_function = 1.6232659059440535e-24
# Generation 22713, loss_function = 1.6190194676912488e-24
# Generation 22714, loss_function = 1.6145349906602937e-24
# Generation 22715, loss_function = 1.612797918946997e-24
# Generation 22716, loss_function = 1.6083225138164519e-24
# Generation 22717, loss_function = 1.604096585947183e-24
# Generation 22718, loss_function = 1.6005279764271894e-24
# Generation 22719, loss_function = 1.5967748227591807e-24
# Generation 22720, loss_function = 1.5931686930423825e-24
# Generation 22721, loss_function = 1.5897034736047795e-24
# Generation 22722, loss_function = 1.5860989216097918e-24
# Generation 22723, loss_function = 1.5824155328280886e-24
# Generation 22724, loss_function = 1.578222737116839e-24
# Generation 22725, loss_function = 1.5745484202355458e-24
# Generation 22726, loss_function = 1.5713282900204336e-24
# Generation 22727, loss_function = 1.567521247291837e-24
# Generation 22728, loss_function = 1.5639467706188609e-24
# Generation 22729, loss_function = 1.5602376945539314e-24
# Generation 22730, loss_function = 1.5555126642506904e-24
# Generation 22731, loss_function = 1.5528358126802427e-24
# Generation 22732, loss_function = 1.5492798742385392e-24
# Generation 22733, loss_function = 1.5464689163142039e-24
# Generation 22734, loss_function = 1.5420858079095696e-24
# Generation 22735, loss_function = 1.537946654739875e-24
# Generation 22736, loss_function = 1.5335757736792717e-24
# Generation 22737, loss_function = 1.5318828781766674e-24
# Generation 22738, loss_function = 1.527521069016474e-24
# Generation 22739, loss_function = 1.5234024262303152e-24
# Generation 22740, loss_function = 1.5199253245753273e-24
# Generation 22741, loss_function = 1.5162684119377555e-24
# Generation 22742, loss_function = 1.512753790085963e-24
# Generation 22743, loss_function = 1.5101145080161264e-24
# Generation 22744, loss_function = 1.5054670819044366e-24
# Generation 22745, loss_function = 1.5022767311884965e-24
# Generation 22746, loss_function = 1.4981912205603569e-24
# Generation 22747, loss_function = 1.4946115669876902e-24
# Generation 22748, loss_function = 1.491473478306721e-24
# Generation 22749, loss_function = 1.4877658320521823e-24
# Generation 22750, loss_function = 1.4842828632442118e-24
# Generation 22751, loss_function = 1.4806700282097193e-24
# Generation 22752, loss_function = 1.4767961788232118e-24
# Generation 22753, loss_function = 1.473459050675094e-24
# Generation 22754, loss_function = 1.4699946200983962e-24
# Generation 22755, loss_function = 1.4672578150991516e-24
# Generation 22756, loss_function = 1.4629883026648692e-24
# Generation 22757, loss_function = 1.4589564345782846e-24
# Generation 22758, loss_function = 1.4546991494880331e-24
# Generation 22759, loss_function = 1.4530504301961212e-24
# Generation 22760, loss_function = 1.4488022170062798e-24
# Generation 22761, loss_function = 1.444790859303231e-24
# Generation 22762, loss_function = 1.4414052655132486e-24
# Generation 22763, loss_function = 1.4378445939061139e-24
# Generation 22764, loss_function = 1.434421479919327e-24
# Generation 22765, loss_function = 1.4311329653244935e-24
# Generation 22766, loss_function = 1.427714584503138e-24
# Generation 22767, loss_function = 1.4242205223386878e-24
# Generation 22768, loss_function = 1.4202422967936582e-24
# Generation 22769, loss_function = 1.4167573065296181e-24
# Generation 22770, loss_function = 1.413701259382792e-24
# Generation 22771, loss_function = 1.410093009602311e-24
# Generation 22772, loss_function = 1.4067015486593462e-24
# Generation 22773, loss_function = 1.4031849546552906e-24
# Generation 22774, loss_function = 1.3987028935108577e-24
# Generation 22775, loss_function = 1.3961648814597288e-24
# Generation 22776, loss_function = 1.3927919587480367e-24
# Generation 22777, loss_function = 1.3901293066738829e-24
# Generation 22778, loss_function = 1.3859733902099523e-24
# Generation 22779, loss_function = 1.3820488072064777e-24
# Generation 22780, loss_function = 1.377905118086578e-24
# Generation 22781, loss_function = 1.3763005750053585e-24
# Generation 22782, loss_function = 1.3721659577858689e-24
# Generation 22783, loss_function = 1.3682618851659301e-24
# Generation 22784, loss_function = 1.3649677992409535e-24
# Generation 22785, loss_function = 1.3615033686642557e-24
# Generation 22786, loss_function = 1.3581717625424745e-24
# Generation 22787, loss_function = 1.3556713199919567e-24
# Generation 22788, loss_function = 1.351266863039075e-24
# Generation 22789, loss_function = 1.3482469062786626e-24
# Generation 22790, loss_function = 1.3443759658167431e-24
# Generation 22791, loss_function = 1.3409856388613295e-24
# Generation 22792, loss_function = 1.3380116332486463e-24
# Generation 22793, loss_function = 1.3345027799422232e-24
# Generation 22794, loss_function = 1.331202826864264e-24
# Generation 22795, loss_function = 1.3277824738906454e-24
# Generation 22796, loss_function = 1.3241137283394954e-24
# Generation 22797, loss_function = 1.3209533050341471e-24
# Generation 22798, loss_function = 1.3176718901874606e-24
# Generation 22799, loss_function = 1.3150833910383976e-24
# Generation 22800, loss_function = 1.3110410705448188e-24
# Generation 22801, loss_function = 1.3072237726244543e-24
# Generation 22802, loss_function = 1.3031936794749065e-24
# Generation 22803, loss_function = 1.3016333126043793e-24
# Generation 22804, loss_function = 1.2976122913552415e-24
# Generation 22805, loss_function = 1.2938155038184128e-24
# Generation 22806, loss_function = 1.2906129257584418e-24
# Generation 22807, loss_function = 1.287244736212181e-24
# Generation 22808, loss_function = 1.2840046379554054e-24
# Generation 22809, loss_function = 1.2808928282033414e-24
# Generation 22810, loss_function = 1.2775367673934983e-24
# Generation 22811, loss_function = 1.2743245257874383e-24
# Generation 22812, loss_function = 1.272781513856826e-24
# Generation 22813, loss_function = 1.2694533096976986e-24
# Generation 22814, loss_function = 1.2673269351276753e-24
# Generation 22815, loss_function = 1.2640393573051668e-24
# Generation 22816, loss_function = 1.261884189312103e-24
# Generation 22817, loss_function = 1.2595523164762697e-24
# Generation 22818, loss_function = 1.2562235699752699e-24
# Generation 22819, loss_function = 1.253451069020064e-24
# Generation 22820, loss_function = 1.250422237574468e-24
# Generation 22821, loss_function = 1.2478243213983489e-24
# Generation 22822, loss_function = 1.2450157793605358e-24
# Generation 22823, loss_function = 1.2420883165412606e-24
# Generation 22824, loss_function = 1.2396211540601819e-24
# Generation 22825, loss_function = 1.2376888885766496e-24
# Generation 22826, loss_function = 1.233858574451349e-24
# Generation 22827, loss_function = 1.2305648336530184e-24
# Generation 22828, loss_function = 1.228261359809773e-24
# Generation 22829, loss_function = 1.226140901696539e-24
# Generation 22830, loss_function = 1.2229030221110593e-24
# Generation 22831, loss_function = 1.2208168794472023e-24
# Generation 22832, loss_function = 1.2175565173259239e-24
# Generation 22833, loss_function = 1.2150686965498897e-24
# Generation 22834, loss_function = 1.2127782389115805e-24
# Generation 22835, loss_function = 1.2096484332701161e-24
# Generation 22836, loss_function = 1.2064179985594295e-24
# Generation 22837, loss_function = 1.2045269017543884e-24
# Generation 22838, loss_function = 1.2017664802317938e-24
# Generation 22839, loss_function = 1.1990111863050831e-24
# Generation 22840, loss_function = 1.197125217095926e-24
# Generation 22841, loss_function = 1.193507895415035e-24
# Generation 22842, loss_function = 1.1908053072575544e-24
# Generation 22843, loss_function = 1.188539304307307e-24
# Generation 22844, loss_function = 1.1860809672076055e-24
# Generation 22845, loss_function = 1.1828663590188299e-24
# Generation 22846, loss_function = 1.1799562511394696e-24
# Generation 22847, loss_function = 1.1776385777999302e-24
# Generation 22848, loss_function = 1.1755622958973885e-24
# Generation 22849, loss_function = 1.1733093091520773e-24
# Generation 22850, loss_function = 1.1700981029259555e-24
# Generation 22851, loss_function = 1.1663742850228597e-24
# Generation 22852, loss_function = 1.1644995077777954e-24
# Generation 22853, loss_function = 1.1621104425263335e-24
# Generation 22854, loss_function = 1.1592823761811162e-24
# Generation 22855, loss_function = 1.156575202769624e-24
# Generation 22856, loss_function = 1.1540770774980154e-24
# Generation 22857, loss_function = 1.1511705194927285e-24
# Generation 22858, loss_function = 1.1485172351418243e-24
# Generation 22859, loss_function = 1.146290675236838e-24
# Generation 22860, loss_function = 1.1431164468656483e-24
# Generation 22861, loss_function = 1.1407206762964921e-24
# Generation 22862, loss_function = 1.1379770180681334e-24
# Generation 22863, loss_function = 1.1355859806644085e-24
# Generation 22864, loss_function = 1.1327902576163053e-24
# Generation 22865, loss_function = 1.1313355981070777e-24
# Generation 22866, loss_function = 1.1283126831182708e-24
# Generation 22867, loss_function = 1.1251637969036614e-24
# Generation 22868, loss_function = 1.1232790109858621e-24
# Generation 22869, loss_function = 1.1203394687339757e-24
# Generation 22870, loss_function = 1.1174755092175709e-24
# Generation 22871, loss_function = 1.1149044143122293e-24
# Generation 22872, loss_function = 1.113089442584542e-24
# Generation 22873, loss_function = 1.1095983386484864e-24
# Generation 22874, loss_function = 1.1072660713822005e-24
# Generation 22875, loss_function = 1.1048072412444332e-24
# Generation 22876, loss_function = 1.1024412008706425e-24
# Generation 22877, loss_function = 1.0993401886522187e-24
# Generation 22878, loss_function = 1.0965310549687267e-24
# Generation 22879, loss_function = 1.0942985786069512e-24
# Generation 22880, loss_function = 1.0923011827949316e-24
# Generation 22881, loss_function = 1.0901270821401425e-24
# Generation 22882, loss_function = 1.087045002583444e-24
# Generation 22883, loss_function = 1.08344212691788e-24
# Generation 22884, loss_function = 1.0814784549095585e-24
# Generation 22885, loss_function = 1.0793336900196823e-24
# Generation 22886, loss_function = 1.076521795323022e-24
# Generation 22887, loss_function = 1.073998820932899e-24
# Generation 22888, loss_function = 1.072129812233204e-24
# Generation 22889, loss_function = 1.069016375455523e-24
# Generation 22890, loss_function = 1.0665016841049047e-24
# Generation 22891, loss_function = 1.0640890023300929e-24
# Generation 22892, loss_function = 1.061581016297169e-24
# Generation 22893, loss_function = 1.059017415570427e-24
# Generation 22894, loss_function = 1.0560790566098984e-24
# Generation 22895, loss_function = 1.0537763716275583e-24
# Generation 22896, loss_function = 1.0517288831480572e-24
# Generation 22897, loss_function = 1.048953276053037e-24
# Generation 22898, loss_function = 1.0467712867891957e-24
# Generation 22899, loss_function = 1.0440299951435527e-24
# Generation 22900, loss_function = 1.041922996969514e-24
# Generation 22901, loss_function = 1.0387141080223012e-24
# Generation 22902, loss_function = 1.0363332765065376e-24
# Generation 22903, loss_function = 1.0340791064698685e-24
# Generation 22904, loss_function = 1.0314119677493163e-24
# Generation 22905, loss_function = 1.0289690627410731e-24
# Generation 22906, loss_function = 1.0265024919056733e-24
# Generation 22907, loss_function = 1.0237608058295777e-24
# Generation 22908, loss_function = 1.0209550741087395e-24
# Generation 22909, loss_function = 1.018874798597865e-24
# Generation 22910, loss_function = 1.0161666391102413e-24
# Generation 22911, loss_function = 1.0140193597262297e-24
# Generation 22912, loss_function = 1.0112934508682385e-24
# Generation 22913, loss_function = 1.0100056354404652e-24
# Generation 22914, loss_function = 1.0070371518541186e-24
# Generation 22915, loss_function = 1.0044575766940459e-24
# Generation 22916, loss_function = 1.0016780745983062e-24
# Generation 22917, loss_function = 9.996177178252886e-25
# w:  [[1.5]
#  [0.5]]
# Loss function:  9.996177178252886e-25
